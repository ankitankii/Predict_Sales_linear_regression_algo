# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
accident=pd.read_csv('C:/python/road_acc_pr/Accidents_2016.csv')
casuality=pd.read_csv('C:/python/road_acc_pr/Casuality_details.csv')
vehicle=pd.read_csv('C:/python/road_acc_pr/Vehicle_details.csv')
makemodel=pd.read_csv('C:/python/road_acc_pr/MakeModel2016.csv')
accident.replace(0,np.nan)
accident.dropna().head()
casuality.dropna().head()
vehicle.dropna().head()
# Out:
#   Accident_Index  Vehicle_Reference  Vehicle_Type  Towing_and_Articulation  \
# 0    2.01601E+12                  1             8                        0
# 1    2.01601E+12                  2             2                        0
# 2    2.01601E+12                  1             9                        0
# 3    2.01601E+12                  1             9                        0
# 4    2.01601E+12                  1            11                        0
#
#    Vehicle_Manoeuvre  Vehicle_Location-Restricted_Lane  Junction_Location  \
# 0                  6                                 0                  0
# 1                 18                                 0                  0
# 2                 18                                 0                  2
# 3                 18                                 0                  4
# 4                 18                                 0                  1
#
#    Skidding_and_Overturning  Hit_Object_in_Carriageway  \
# ...

# %%
merged_acc_veh = pd.merge(accident,vehicle, on= "Accident_Index", how= "inner")
merged_acc_veh
merged_acc_veh_cas = pd.merge(merged_acc_veh,casuality, on= "Accident_Index", how= "inner")
#merged_acc_veh_cas.to_csv('C:/python/road_acc_pr/merged_acc_veh_cas.csv')
merged_acv=pd.read_csv('C:/python/road_acc_pr/merged_acc_veh_cas.csv')
merged_acv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 0                0  2016010X31538               548440.0
# 1                1  2016010X31538               548440.0
# 2                2  2016010X31762               553100.0
# 3                3  2016010X31762               553100.0
# 4                4  2016010X31762               553100.0
# 5                5  2016010X31762               553100.0
# 6                6  201601BS70001               527670.0
# 7                7  201601BS70002               526280.0
# 8                8  201601BS70002               526280.0
# 9                9  201601BS70003               523590.0
# 10              10  201601BS70003               523590.0
# ...

# %%
#1.How many Males and Females were involved in accidents?
casuality['Sex_of_Casualty'].value_counts()
casuality['Sex_of_Casualty'].hist()
plt.show()

# %%
#2-	Which is the most dangerous time to travel (on the basis of number of accidents)?
n=accident['Time'].value_counts()
n.tail(10)
df=accident.groupby(["Time"])[['Number_of_Casualties']].count()
print(df.sort_values(by=['Number_of_Casualties'],ascending=False).head())
#3-	Which is the safest time to travel (on the basis of number of accidents)?
print(df.sort_values(by=['Number_of_Casualties']).head())
# Out:
#        Number_of_Casualties
# Time
# 17:00                  1317
# 18:00                  1263
# 17:30                  1255
# 16:00                  1143
# 15:00                  1133
#        Number_of_Casualties
# Time
# 05:07                     2
# 02:01                     2
# 04:46                     2
# 04:29                     2
# 04:01                     2

# %%
#4-	Which make and model cars are more accident prone?
#makemodel.groupby(['make'])[['model']].count()
makemodel['make-model']=makemodel['make'].astype(str) +' - '+makemodel['model'].astype(str)
makemodel['make-model'].value_counts().head()
# Out:
# nan - nan                     47725
# VOLVO - Missing                1802
# FORD - FIESTA ZETEC            1764
# DAF TRUCKS - Missing           1193
# ALEXANDER DENNIS - Missing     1187
# Name: make-model, dtype: int64

# %%
#5-	How many fatal accidents, Serious accidents and Slight accidents were recorded?
sel_acc_sev=accident.iloc[:,6]
sel_acc_sev.loc[accident.Accident_Severity==3].count()
# Out:
# 113201

# %%
accident['Accident_Severity'].hist()
plt.show()

# %%
#6-	What were the Road surface conditions in Fatal accidents?
fatal_road=accident.loc[accident.Accident_Severity==1]
#print(fatal_road.groupby(['Accident_Severity'])[['Road_Type']].count())
fatal_road.iloc[:,[6,16]]
fatal_road['Road_Type'].value_counts()
# Out:
# 6    1282
# 3     339
# 1      26
# 2      22
# 7      16
# 9      10
# Name: Road_Type, dtype: int64

# %%
#7-	How many cycling Accidents were there?
vehicle.loc[vehicle.Vehicle_Type==1].count()
# Out:
# Accident_Index                      19047
# Vehicle_Reference                   19047
# Vehicle_Type                        19047
# Towing_and_Articulation             19047
# Vehicle_Manoeuvre                   19047
# Vehicle_Location-Restricted_Lane    19047
# Junction_Location                   19047
# Skidding_and_Overturning            19047
# Hit_Object_in_Carriageway           19047
# Vehicle_Leaving_Carriageway         19047
# Hit_Object_off_Carriageway          19047
# 1st_Point_of_Impact                 19047
# Was_Vehicle_Left_Hand_Drive?        19047
# Journey_Purpose_of_Driver           19047
# Sex_of_Driver                       19047
# Age_of_Driver                       19047
# Age_Band_of_Driver                  19047
# Engine_Capacity_(CC)                19047
# Propulsion_Code                     19047
# Age_of_Vehicle                      19047
# Driver_IMD_Decile                   19047
# Driver_Home_Area_Type               19047
# ...

# %%
#8-	Find the number of accidents in each Light condition?
accident['Light_Conditions'].value_counts()
# Out:
#  1    98969
#  4    27569
#  6     7019
#  7     2194
#  5      857
# -1       13
# Name: Light_Conditions, dtype: int64

# %%
#9-	Is weather an important factor for accident? How many accidents happened in a fogy, snowy and rainy weather.

accident['Weather_Conditions'].value_counts()
# Out:
#  1    112241
#  2     14492
#  9      3813
#  8      2244
#  5      1386
#  4      1262
#  7       745
#  3       346
#  6        79
# -1        13
# Name: Weather_Conditions, dtype: int64

# %%
#10-	Is there any particular vehicle which is more accident prone? Vehicle_Type
vehicle['Vehicle_Type'].value_counts()
# Out:
#  9     179615
#  1      19047
#  19     13125
#  3       9152
#  5       6704
#  8       5234
#  11      4998
#  21      4262
#  4       2232
#  2       1907
#  20      1557
#  90      1431
#  98      1088
#  17       531
#  10       458
#  97       366
# -1        336
#  22       260
#  16       113
#  23        62
#  18        22
# Name: Vehicle_Type, dtype: int64

# %%
accident.hist(figsize=(20,20))
plt.show()

# %%
#accident['Month']=test['Month'].astype(str
accident=pd.read_csv('C:/python/road_acc_pr/Accidents_2016.csv')
accident['Time']=accident['Time'].replace(['17:01', '17:02', '17:03', '17:04', '17:05', '17:06', '17:07', '17:08', '17:09', '17:10', '17:00', '17:00', '17:11', '17:12', '17:13', '17:14', '17:15', '17:16', '17:17', '17:18', '17:19', '17:20', '17:21', '17:22', '17:23', '17:24', '17:25', '17:26', '17:27', '17:28', '17:29', '17:30', '17:31', '17:32', '17:33', '17:34', '17:35', '17:36', '17:37', '17:38', '17:39', '17:40', '17:41', '17:42', '17:43', '17:44', '17:45', '17:46', '17:47', '17:48', '17:49', '17:50', '17:51', '17:52', '17:53', '17:54', '17:55', '17:56', '17:57', '17:58', '17:59'], '17:00'  )
j=accident['Time'].value_counts() 
j
# Out:
# 17:00    12068
# 18:00     1263
# 16:00     1143
# 15:00     1133
# 16:30     1115
# 15:30     1110
# 08:30     1040
# 14:00      966
# 18:30      965
# 13:00      941
# 19:00      873
# 08:00      865
# 14:30      837
# 12:00      836
# 09:00      825
# 13:30      811
# 12:30      763
# 16:45      717
# 11:00      701
# 10:00      680
# 08:45      679
# 11:30      669
# 15:15      661
# 16:20      642
# 20:00      641
# 19:30      640
# 10:30      634
# 16:15      632
# 08:20      623
# 09:30      622
#          ...
# 04:56        5
# 01:49        5
# 04:22        5
# 04:13        4
# 04:54        4
# 04:03        4
# 03:42        4
# 05:16        4
# 03:23        4
# 02:52        4
# 03:14        4
# 05:03        4
# 02:17        4
# 04:34        4
# 05:26        3
# 03:06        3
# 02:56        3
# 02:36        3
# 04:42        3
# 04:43        3
# 03:59        3
# 04:47        3
# 04:28        3
# 04:01        2
# 05:07        2
# 02:01        2
# 04:46        2
# ...
